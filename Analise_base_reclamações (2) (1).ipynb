# %% [markdown]
# # Processamento Inicial

# %% [markdown]
# ### Importa bibliotecas

# %%
import nltk
import pandas as pd
import os
import numpy as np
import string
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Define o diretório de trabalho

# %%
#workdir_path = '/mnt/5bdd0b49-a2cd-495d-a27b-f4810abd97ca/home/osias/Projects/'+\
#'Processamento de linguagem natural/Trabalho BI 2019'
#os.chdir(workdir_path)

# %% [markdown]
# ### Leitura da base de reclamações

# %%
data = pd.read_csv('BaseReclamacoes.csv',encoding='windows-1252',sep =';')
# verificação visual das 5 primeiras linhas
data.tail()
# Out:
#        Regiao  estado                                     empresa  \
# 42302  Sudeste     SP                       B2W COMPANHIA DIGITAL
# 42303  Sudeste     SP                       ADIDAS DO BRASIL LTDA
# 42304  Sudeste     SP                   RN COMERCIO VAREJISTA S/A
# 42305  Sudeste     SP                            DECOLAR.COM LTDA
# 42306  Sudeste     SP  ESAB ESCOLA SUPERIOR ABERTA DO BRASIL LTDA
#
#                                            subsidiaria    \
# 42302        AMERICANAS.COM/SUBMARINO/SHOPTIME/SOUBARATO
# 42303                                      ADIDAS.COM.BR
# 42304  RICARDOELETRO.COM.BR/INSINUANTE.COM/ELETROSHOP...
# 42305                                    AGÊNCIA DECOLAR
# 42306                                                NaN
#
#                                                    area   \
# 42302  COMÉRCIO VAREJISTA DE OUTROS PRODUTOS NÃO ESPE...
# 42303                    COMÉRCIO ATACADISTA DE CALÇADOS
# 42304  COMÉRCIO VAREJISTA ESPECIALIZADO DE ELETRODOMÉ...
# 42305                                AGÊNCIAS DE VIAGENS
# 42306      EDUCAÇÃO SUPERIOR - GRADUAÇÃO E PÓS-GRADUAÇÃO
#
#                                                  serviço  \
# 42302          Microcomputador / Produtos de Informática
# 42303                      Vestuário ( Calçado / Roupa )
# 42304  Acessório Para Vestuário ( Bolsa, Cinto, Chapé...
# 42305  Agências e Operadoras de viagens (pacotes turí...
# 42306            Escola ( Pré, 1º, 2º Graus e Superior )
#
#                                                 problema        faixa etarea
# 42302           Não entrega/demora na entrega do produto       Nao Informada
# 42303           Não entrega/demora na entrega do produto  entre 31 a 40 anos
# 42304               Produto entregue diferente do pedido  entre 21 a 30 anos
# 42305            Recusa injustificada em prestar serviço       Nao Informada
# 42306  Serviço não fornecido (entrega/instalação/não ...  entre 31 a 40 anos

# %% [markdown]
# ### Quantidade de linhas e de colunas do dataframe lido

# %%
data.shape
# Out:
# (42307, 8)

# %% [markdown]
# ## Colunas da tabela

# %%
data.columns
# Out:
# Index(['Regiao ', 'estado', 'empresa', 'subsidiaria  ', 'area ', 'serviço',
#        'problema', 'faixa etarea'],
#       dtype='object')

# %% [markdown]
# ### Localização das colunas com valores "null"

# %%
data.isnull().sum()
# Out:
# Regiao              0
# estado              0
# empresa             1
# subsidiaria      6530
# area             5329
# serviço             0
# problema         8936
# faixa etarea        0
# dtype: int64

# %% [markdown]
# # Tratamento das empresas

# %% [markdown]
# ### Separação da coluna das empresas

# %%
df_empresa = pd.DataFrame()
df_empresa['empresa'] = data['empresa']

# %% [markdown]
# ### Verificação se há algum "null"

# %%
df_empresa.isnull().sum()
# Out:
# empresa    1
# dtype: int64

# %% [markdown]
# ### Remoção dos "nulls" encontrados

# %%
df_empresa.dropna(inplace=True)
df_empresa.isnull().sum()
# Out:
# empresa    0
# dtype: int64

# %% [markdown]
# ### Substitui:

# %% [markdown]
# #### " " por "_" (espaço)

# %% [markdown]
# #### "/" por ""

# %% [markdown]
# #### "," por ""

# %% [markdown]
# #### "(" por ""

# %% [markdown]
# #### ")" por ""

# %% [markdown]
# #### "-" por ""

# %% [markdown]
# #### "." por ""

# %% [markdown]
# #### "\t" por "" (tab)

# %% [markdown]
# ### para o wordcloud funcionar

# %%
dicionario = {' ':'_','/':'',',':'','\(':'','\)':'',"-":'','\.':'',r"^\t":''}
df_empresa["Nome Empresa Sem Espaço"] = df_empresa.replace({'empresa': dicionario},regex=True)

# %% [markdown]
# ### Converte o nome das empresas para letras minúsculas

# %%
df_empresa["Nome Empresa Sem Espaço"] = df_empresa["Nome Empresa Sem Espaço"].str.lower()

# %% [markdown]
# ### Apreciação inicial do que foi obtido

# %%
print (df_empresa.groupby("Nome Empresa Sem Espaço").size().sort_values(ascending=False))
# Out:
# Nome Empresa Sem Espaço
# telefonica_brasil_sa                                  1150
# claro_sa                                              1125
# tim_celular_sa                                         786
# via_varejo_sa                                          516
# eletropaulo_metropolitana_eletricidade_de_s_paulo      480
#                                                       ...
# flynt_consultoria_comercial__eireli                      1
# fls_educacional_consultoria_e_assessoria_em_inform       1
# flp_comercial_de_medicamentos_ltda_me                    1
# florismagno_dos_santos_cerqueira__me                     1
# única_brasilia_automoveis_ltda_smaff_ford                1
# Length: 10607, dtype: int64

# %% [markdown]
# ### Criação de uma string única com todas as ocorrências dos nomes das empresas

# %%
string_empresas = " ".join([text for text in df_empresa["Nome Empresa Sem Espaço"]])

# %% [markdown]
# ### Geração do wordcloud das 40 empresas mais reclamadas

# %%
wordcloud_empresas = WordCloud(background_color="black",collocations=False,
                              colormap="Oranges_r",
                              width = 3000,
                              height = 2000,
                              max_font_size=1000,
                              max_words=40
                             ).generate(string_empresas)
plt.figure(figsize = (40,30),
           facecolor = 'k',
           edgecolor = 'k')
plt.imshow(wordcloud_empresas, interpolation='bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.savefig("Empresa_wordcloud.png")
plt.show()

# %% [markdown]
# ### Para ficar mais claro, é interessante um diagrama de barras ordenado pela quantidade decrescente de problemas, limitado aos 45 mais reclamados.

# %%
# Inicializa a figura do matplotlib
f, ax = plt.subplots(figsize=(40,40))
# Inicializa estilo do seaborn
sns.set(style="ticks",font_scale=3.5)
# carrega o dataset
sns.countplot(y = "problema", data=df_problema,
              order = df_problema["problema"].value_counts().index[:45])
ax.grid(True)
ax.set_title("Reclamações por problema")
ax.set_ylabel('Problema')
ax.set_xlabel('Reclamações')
plt.tight_layout(pad=0)
plt.savefig("Problema_barplot.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-54263e677bb0> in <module>
#       4 sns.set(style="ticks",font_scale=3.5)
#       5 # carrega o dataset
# ----> 6 sns.countplot(y = "problema", data=df_problema,
#       7               order = df_problema["problema"].value_counts().index[:45])
#       8 ax.grid(True)
#
# NameError: name 'df_problema' is not defined
